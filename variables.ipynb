# %%
can="soda"

# %%
can
# Out:
# 'soda'

# %%
can="beans"
can
# Out:
# 'beans'

# %%
type(can)
# Out:
# str

# %%
pizza=100
type(pizza)
# Out:
# int

# %%
samosa=20.5
icecream=100

# %%
total=samosa+icecream+pizza
total
# Out:
# 220.5

# %%
type(total)
# Out:
# float

# %%
total > 200
# Out:
# True

# %%
total < 200
# Out:
# False

# %%
above_threshold=total>200
above_threshold
# Out:
# True

# %%
foo="jalebi"
foo
# Out:
# 'jalebi'

# %%
bar=foo
bar
# Out:
# 'jalebi'

# %%
id(foo)
# Out:
# 1690562427328

# %%
id(bar)
# Out:
# 1690562427328

# %%
#can't give variable name like true=5 because true is reserved keyword in python, ex: def
$name="daval"
abc^=100
# Out:
#   Cell In[16], line 2
#     $name="daval"
#     ^
# SyntaxError: invalid syntax

# %%
# varaiable name must begin with letter or _ (underscore)
_pizza=100

# %%
_pizza
# Out:
# 100
