# %%
items=['bread','butter','pasta','cheese']

# %%
items[0]
# Out:
# 'bread'

# %%
for item in items:
    print(item)
# Out:
# bread
# butter
# pasta
# cheese

# %%
items[0:2]
# Out:
# ['bread', 'butter']

# %%
items.append('butter')

# %%
items
# Out:
# ['bread', 'butter', 'pasta', 'cheese', 'butter']

# %%
items.remove('butter')

# %%
items
# Out:
# ['bread', 'butter', 'butter', 'pasta', 'cheese', 'butter']

# %%
items.insert('butter',1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 items.insert('butter',1)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
items.insert(1,'butter')
items
# Out:
# ['bread', 'butter', 'butter', 'butter', 'pasta', 'cheese', 'butter']

# %%
items[1]='cheese'

# %%
items
# Out:
# ['bread', 'cheese', 'butter', 'butter', 'pasta', 'cheese', 'butter']

# %%
items[3:]=['almonds']
items
# Out:
# ['bread', 'cheese', 'butter', 'almonds']

# %%
'rice' in items
# Out:
# False

# %%
'bread' in items
# Out:
# True

# %%
expenses=[30,1200,45,300]
expenses.sort()

# %%
expenses
# Out:
# [30, 45, 300, 1200]

# %%
expenses.sort(reverse=True)

# %%
expenses
# Out:
# [1200, 300, 45, 30]

# %%
food_items=['aaa','bb']
bathroom_items=['ddd','vvv']
al=food_items+bathroom_items

# %%
al
# Out:
# ['aaa', 'bb', 'ddd', 'vvv']

# %%
items.clear()
items
# Out:
# []

# %%
random=['car',4.5,True]
random
# Out:
# ['car', 4.5, True]

# %% [markdown]
# ![image.png](attachment:8a413f6b-7793-4732-bfe9-30ed11b03692.png)
