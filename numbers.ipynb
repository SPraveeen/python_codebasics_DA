# %%
# area of a triangle
base=10
height=7

area=(base*height)/2
area
# Out:
# 35.0

# %%
type(area)
# Out:
# float

# %%
x=10
y=3
print(x+y)
print(x/y)
print(x//y)
print(x%y)
# Out:
# 13
# 3.3333333333333335
# 3
# 1

# %% [markdown]
# ![image.png](attachment:3463a868-b395-4da1-a4ca-799ee0adba8b.png)

# %%
x,y
# Out:
# (10, 3)

# %%
x**y
# Out:
# 1000

# %%
10+2*3
# Out:
# 16

# %%
(10+2)*3
# Out:
# 36

# %% [markdown]
# # scientific notattion

# %%
foo=2.3e4

# %%
foo
# Out:
# 23000.0

# %%
1e4
# Out:
# 10000.0

# %%
1e-3
# Out:
# 0.001

# %%
bar=2.3e-4

# %%
bar
# Out:
# 0.00023

# %%
food=120.34
rent=500.4
utilities=200.5

# %%
total=food+rent+utilities
total
# Out:
# 821.24

# %%
round(total)
# Out:
# 821

# %%
round(total,1)
# Out:
# 821.2

# %%
income=10000
expenses=9000
saving=income-expenses
saving
# Out:
# 1000

# %%
food="120.34"
rent="500.67"
total1=food+rent
total=float(food)+float(rent)
print(total1)
print(total)
# Out:
# 120.34500.67
# 621.01

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
math.floor(3.7)
# Out:
# 3

# %%
math.ceil(3.7)
# Out:
# 4

# %%
math.pi
# Out:
# 3.141592653589793

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
format(5,'b')
# Out:
# '101'

# %% [markdown]
# ![image.png](attachment:855ab28b-2a23-4274-81ce-04f78b246693.png)
