# %%
#like java c++ how main was there here in python we have main function
# to define or use that 
# if __name__=="__main__"

def calculate_triangle(base,height):
    print("value of __name__: ",__name__)
    return (base*height)/2

if __name__=='__main__':
    print("area:", calculate_triangle(10,2))
# Out:
# value of __name__:  __main__
# area: 10.0

# %%
import numpy as np
np.__name__
# Out:
# 'numpy'

# %%
import pandas as pd
pd.__name__
# Out:
# 'pandas'

# %% [markdown]
# ![image.png](attachment:98d81a93-10e3-498f-98a9-0255b550d230.png)
