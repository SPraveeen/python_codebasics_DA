# %% [markdown]
# # tuples are immutable and fixed in size , so they are memory optimized

# %%
expenses=[1200,1400,1700]

# %%
point=[5,6]
point[0]
# Out:
# 5

# %%
point1=(5,6)
point1[0]
# Out:
# 5

# %%
type(point1)
# Out:
# tuple

# %%
point_3d=(5,8,10)

# %%
def find_pe_and_pb(price,eps,book_value):
    pe=price/eps
    pb=price/book_value
    return pe,pb

# %%
pe_ratio,pb_ratio=find_pe_and_pb(100,2,4)

# %%
pe_ratio
# Out:
# 50.0

# %%
pb_ratio
# Out:
# 25.0

# %%
contacts=[('rachael',9876543245),('monica',6789543268),('joey',78654234566)]

# %% [markdown]
# # dictionary like name and phone number storage like that, key value pair

# %%
# to find one value it's not better approach/using hashmap was one convinient way

for contact in contacts:
    if contact[0]=='monica':
        print(contact[1])
# Out:
# 6789543268

# %%
d={
    'rachel':33333,
    'monica':22222,
    'joey':11111
}

# %%
type(d)
# Out:
# dict

# %%
d['joey']
# Out:
# 11111

# %%
 d.get('joey')
# Out:
# 11111

# %%
d['rachel']=0000

# %%
d
# Out:
# {'rachel': 0, 'monica': 22222, 'joey': 11111}

# %%
d['satya']=8888

# %%
d
# Out:
# {'rachel': 0, 'monica': 22222, 'joey': 11111, 'satya': 8888}

# %%
del d['satya']

# %%
d
# Out:
# {'rachel': 0, 'monica': 22222, 'joey': 11111}

# %%
'abdul' in d
# Out:
# False

# %%
'joey' in d
# Out:
# True

# %%
#dict inside d
contact_dict={
    'rachel':{'phone':7777,'address':'1 blue st'},
    'joey':{'phone':999,'address':'7 newton blvd'}
}

# %%
contact_dict['rachel']['phone']
# Out:
# 7777

# %%
contact_dict['rachel']
# Out:
# {'phone': 7777, 'address': '1 blue st'}

# %%
for name in d:
    print(name)
# Out:
# rachel
# monica
# joey

# %%
for name,number in d.items():
    print(name,number)
# Out:
# rachel 0
# monica 22222
# joey 11111

# %%
d.keys()
# Out:
# dict_keys(['rachel', 'monica', 'joey'])

# %%
d.values()
# Out:
# dict_values([0, 22222, 11111])

# %% [markdown]
# ![image.png](attachment:199d6877-0d28-4985-bb7f-f5c949ba14f8.png)

# %% [markdown]
# ![image.png](attachment:d3bbb5ca-0522-48d6-b461-8b76c921d194.png)

# %% [markdown]
# ![image.png](attachment:ce3a3842-21cc-4da5-8a2d-178cbeba5d61.png)
