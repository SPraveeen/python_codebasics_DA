# %% [markdown]
# - expenses

# %%
expenses=[1200,1300,1400,1700]
for expense in expenses:
    print(expense)
# Out:
# 1200
# 1300
# 1400
# 1700

# %%
total_expense=0
for expense in expenses:
    total_expense+=expense
print(total_expense)
# Out:
# 5600
