# %% [markdown]
# # strings are immutable / can't be changed

# %%
first="mohan"
last="sharma"

# %%
type(first)
# Out:
# str

# %%
name=first+" "+last
name
# Out:
# 'mohan sharma'

# %%
name=f'{first} {last}'
name
# Out:
# 'mohan sharma'

# %%
age=28
info=f'{name} is {age} years old'
info
# Out:
# 'mohan sharma is 28 years old'

# %%
name[0]
# Out:
# 'm'

# %%
name[0:4]
# Out:
# 'moha'

# %%
name[-1]
# Out:
# 'a'

# %%
name[6:]
# Out:
# 'sharma'

# %%
len(name)
# Out:
# 12

# %%
name[0]='s'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 name[0]='s'
#
# TypeError: 'str' object does not support item assignment

# %%
receipe='''
take chicken and put in cooker
'''
receipe
# Out:
# '\ntake chicken and put in cooker\n'

# %%
'take' in receipe
# Out:
# True

# %%
s='pateients was chrged $100 for test'
s
# Out:
# 'pateients was chrged $100 for test'

# %%
s.replace('$100','$10')
# Out:
# 'pateients was chrged $10 for test'

# %%
s.upper()
# Out:
# 'PATEIENTS WAS CHRGED $100 FOR TEST'

# %%
a="ABC"
a.lower()
# Out:
# 'abc'

# %%
'410'.isdigit()
# Out:
# True

# %%
'2e34'.isdigit()
# Out:
# False

# %%
s.index("$")
# Out:
# 21

# %%
s='hey\tbro'
s
# Out:
# 'hey\tbro'

# %%
print(s)
# Out:
# hey	bro

# %%
tickers='AAPL|NVDA|RIL|GOGL'

# %%
tickers.split('|')
# Out:
# ['AAPL', 'NVDA', 'RIL', 'GOGL']

# %%
tickers.split('|',maxsplit=2)
# Out:
# ['AAPL', 'NVDA', 'RIL|GOGL']

# %%
data='    hey, we go for tea  ? '
data
# Out:
# '    hey, we go for tea  ? '

# %%
data.strip()
# Out:
# 'hey, we go for tea  ?'

# %%
file_name='repart.pdf'
file_name.endswith('.pdf')
# Out:
# True

# %% [markdown]
# ![image.png](attachment:f6e00c89-2297-4fd6-aa29-823f6a5c6ec0.png)
